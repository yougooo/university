# %%
import matplotlib.pyplot as plt
from kclass import KMean
from sklearn.datasets.samples_generator import make_blobs

# %%
X, y = make_blobs(n_samples=300, centers=4,
                 random_state=0, cluster_std=0.75)
plt.figure(figsize=(20,10))
plt.scatter(X[:, 0], X[:, 1], s=50)
plt.show()

# %%
test = KMean()
test.fit(X,4)
test.k_mean()[1]
test.visual()

# %%
X, y = make_blobs(n_samples=1000, centers=5,
                 random_state=0, cluster_std=0.25)
plt.figure(figsize=(20,10))
plt.scatter(X[:, 0], X[:, 1], s=50)
plt.show()

# %%
test = KMean()
test.fit(X, 5)
test.k_mean()[1]
test.visual()

# %%
X, y = make_blobs(n_samples=3000, centers=5,
                 random_state=0, cluster_std=0.75)
plt.figure(figsize=(20,10))
plt.scatter(X[:, 0], X[:, 1], s=50)
plt.show()

# %%
test = KMean()
test.fit(X, 5)
test.k_mean()[1]
test.visual()

# %%
X, y = make_blobs(n_samples=3000, centers=7,
                 random_state=1, cluster_std=0.75)
plt.figure(figsize=(20,10))
plt.scatter(X[:, 0], X[:, 1], s=50)
plt.show()

# %%
# trabl 
test = KMean()
test.fit(X, 6)
test.k_mean()
test.visual()

# %%
X, y = make_blobs(n_samples=3000, centers=8,
                 random_state=0, cluster_std=0.90)
plt.figure(figsize=(20,10))
plt.scatter(X[:, 0], X[:, 1], s=50)
plt.show()

# %%
# if put 6 core
test = KMean()
test.fit(X, 6)
test.k_mean()
test.visual()

# %%
# because method depend on start centers
# in my case it was just random choice
# that's why sometime we have had trouble(wrong clasters)
test = KMean()
test.fit(X, 8)
test.k_mean()
test.visual()
